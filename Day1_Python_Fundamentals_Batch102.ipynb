# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello All welcome to the python programming world!!")
# Out:
# Hello All welcome to the python programming world!!

# %%
print("Hello World")
# Out:
# Hello World

# %%
name= input("What is your name?")
print("Hello ," + name)
# Out:
# What is your name? Abdul Noman
# Hello ,Abdul Noman

# %%
name= input("What is your name?")
print("Hello " + name)
# Out:
# What is your name? Abdul Noman
# Hello Abdul Noman
